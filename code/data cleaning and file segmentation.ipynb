# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
# Read script
script = pd.read_csv('/Users/ceciliali/Documents/MSc Data Science/Visual Analytics/coursework_marvel/archive/mcu.csv')
script.head()
# Out:
#    Unnamed: 0       character  \
# 0           0      TONY STARK
# 1           1  IRON MAN JIMMY
# 2           2      TONY STARK
# 3           3         RAMIREZ
# 4           4      TONY STARK
#
#                                                 line     movie  year  words  \
# 0  Oh, I get it.  You guys aren’t allowed to talk...  Iron Man  2008     22
# 1                        No.  We’re allowed to talk.  Iron Man  2008      6
# 2                     Oh.  I see.  So it’s personal.  Iron Man  2008      8
# 3                       I think they’re intimidated.  Iron Man  2008      4
# 4  Good God, you’re a woman. I, honestly, I could...  Iron Man  2008     31
#
#    Adam McKay  Anna Boden  Art Marcum  Ashley Edward Miller  ...  Joss Whedon  \
# 0       False       False        True                 False  ...        False
# 1       False       False        True                 False  ...        False
# 2       False       False        True                 False  ...        False
# ...

# %%
# Delete unrelated columns
script = script.iloc[:, 0:4]
script.head()
# Out:
#    Unnamed: 0       character  \
# 0           0      TONY STARK
# 1           1  IRON MAN JIMMY
# 2           2      TONY STARK
# 3           3         RAMIREZ
# 4           4      TONY STARK
#
#                                                 line     movie
# 0  Oh, I get it.  You guys aren’t allowed to talk...  Iron Man
# 1                        No.  We’re allowed to talk.  Iron Man
# 2                     Oh.  I see.  So it’s personal.  Iron Man
# 3                       I think they’re intimidated.  Iron Man
# 4  Good God, you’re a woman. I, honestly, I could...  Iron Man

# %% [markdown]
# ## Endgame

# %%
# Select Endgame script
endgame = script.loc[script['movie'] == 'Avengers: Endgame']
endgame.head()
# Out:
#        Unnamed: 0     character  \
# 14636       14636  CLINT BARTON
# 14637       14637   LILA BARTON
# 14638       14638  CLINT BARTON
# 14639       14639  LAURA BARTON
# 14640       14640   LILA BARTON
#
#                                                     line              movie
# 14636  Okay, you see where you’re going? Let’s work o...  Avengers: Endgame
# 14637                                         Why three?  Avengers: Endgame
# 14638       ‘Cause two’s not enough and four’s too much-  Avengers: Endgame
# 14639            You guys want mustard or mayo, or both?  Avengers: Endgame
# 14640                        Who puts mayo on a hot dog?  Avengers: Endgame

# %%
# Export csv files
endgame.to_csv(r'/Users/ceciliali/Documents/MSc Data Science/Visual Analytics/coursework_marvel/endgame.csv',
              index=False)

# %% [markdown]
# ## Infinity War

# %%
# Select Infinity script
infinityWar = script.loc[script['movie'] == 'Avengers: Infinity War']
infinityWar.head()
# Out:
#        Unnamed: 0     character  \
# 12998       12998  ASGARDIAN PA
# 12999       12999     EBONY MAW
# 13000       13000        THANOS
# 13001       13001          THOR
# 13002       13002        THANOS
#
#                                                     line  \
# 12998  This is the Asgardian refugee vessel Statesman...
# 12999  Hear me, and rejoice. You have had the privile...
# 13000  I know what it's like to lose. To feel so desp...
# 13001                                 You talk too much.
# 13002  The Tesseract, or your brother's head. I assum...
#
#                         movie
# 12998  Avengers: Infinity War
# 12999  Avengers: Infinity War
# 13000  Avengers: Infinity War
# 13001  Avengers: Infinity War
# 13002  Avengers: Infinity War

# %%
# Export csv files
infinityWar.to_csv(r'/Users/ceciliali/Documents/MSc Data Science/Visual Analytics/coursework_marvel/infinityWar.csv',
              index=False)

# %% [markdown]
# ## The Avengers

# %%
# Select Avenger script
avengers = script.loc[script['movie'] == 'The Avengers']
avengers.head()
# Out:
#       Unnamed: 0       character  \
# 3194        3194       THE OTHER
# 3195        3195  INTERCOM VOICE
# 3196        3196       NICK FURY
# 3197        3197    PHIL COULSON
# 3198        3198       NICK FURY
#
#                                                    line         movie
# 3194  The Tesseract has awakened. It is on a little ...  The Avengers
# 3195  All personnel, evacuation order has been confi...  The Avengers
# 3196                                     How bad is it?  The Avengers
# 3197  That’s the problem, sir. We don’t know. Doctor...  The Avengers
# 3198   NASA didn’t authorize Selvig could go to test B.  The Avengers

# %%
# Export csv files
avengers.to_csv(r'/Users/ceciliali/Documents/MSc Data Science/Visual Analytics/coursework_marvel/avengers.csv',
              index=False)

# %% [markdown]
# ## Age of Ultron

# %%
# Select Infinity script
ultron = script.loc[script['movie'] == 'Avengers: Age of Ultron']
ultron.head()
# Out:
#       Unnamed: 0     character  \
# 6653        6653     ANNOUNCER
# 6654        6654    TONY STARK
# 6655        6655  STEVE ROGERS
# 6656        6656        JARVIS
# 6657        6657          THOR
#
#                                                    line  \
# 6653  Report to your stations immediately. This is n...
# 6654                                              Shit!
# 6655   Language! JARVIS, what's the view from upstairs?
# 6656  The central building is protected by some kind...
# 6657  Loki's scepter must be here. Strucker couldn't...
#
#                         movie
# 6653  Avengers: Age of Ultron
# 6654  Avengers: Age of Ultron
# 6655  Avengers: Age of Ultron
# 6656  Avengers: Age of Ultron
# 6657  Avengers: Age of Ultron

# %%
# Export csv files
ultron.to_csv(r'/Users/ceciliali/Documents/MSc Data Science/Visual Analytics/coursework_marvel/ultron.csv',
              index=False)
