# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
overview = pd.read_csv('characters_overview.csv')

# %%
overview.isna().sum()
# Out:
# character                              0
# Ant-Man                                0
# Avengers: Age of Ultron                0
# Avengers: Endgame                      0
# Avengers: Infinity War                 0
# Black Panther                          0
# Captain America: Civil War             0
# Captain America: The First Avenger     0
# Captain America: The Winter Soldier    0
# Captain Marvel                         0
# Guardians of the Galaxy Vol. 2         0
# Iron Man                               0
# Iron Man 2                             0
# Iron Man 3                             0
# Spider-Man: Homecoming                 0
# The Avengers                           0
# Thor                                   0
# Thor: Ragnarok                         0
# Thor: The Dark World                   0
# total lines                            0
# total words                            0
# movie appearances                      0
# avg words per line                     0
# ...

# %%
overview.describe()
# Out:
#           Ant-Man  Avengers: Age of Ultron  Avengers: Endgame  \
# count  652.000000               652.000000         652.000000
# mean     1.243865                 1.472393           1.648773
# std     11.810604                11.031202          10.097267
# min      0.000000                 0.000000           0.000000
# 25%      0.000000                 0.000000           0.000000
# 50%      0.000000                 0.000000           0.000000
# 75%      0.000000                 0.000000           0.000000
# max    222.000000               173.000000         137.000000
#
#        Avengers: Infinity War  Black Panther  Captain America: Civil War  \
# count              652.000000     652.000000                  652.000000
# mean                 1.427914       1.062883                    1.417178
# std                  8.424747       7.833367                   10.542615
# min                  0.000000       0.000000                    0.000000
# ...

# %%
pd.set_option("display.max_columns", None)
overview.loc[overview['avg words per line']==overview['avg words per line'].max()]
# Out:
#                character  Ant-Man  Avengers: Age of Ultron  Avengers: Endgame  \
# 435  TV REPORTER’S VOICE        0                        0                  0
#
#      Avengers: Infinity War  Black Panther  Captain America: Civil War  \
# 435                       0              0                           0
#
#      Captain America: The First Avenger  Captain America: The Winter Soldier  \
# 435                                   0                                    0
#
#      Captain Marvel  Guardians of the Galaxy Vol. 2  Iron Man  Iron Man 2  \
# 435               0                               0         1           0
#
#      Iron Man 3  Spider-Man: Homecoming  The Avengers  Thor  Thor: Ragnarok  \
# 435           0                       0             0     0               0
#
#      Thor: The Dark World  total lines  total words  movie appearances  \
# 435                     0            1          235                  1
#
#      avg words per line  avg lines per movie
# ...
